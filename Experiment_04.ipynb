# %% [markdown]
# <a href="https://colab.research.google.com/github/YashSawant5151/Simple_Python_Programs/blob/main/Experiment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# # Task
# Compute and display the mean, median, variance, and standard deviation for the generated Normal Distribution data, and then display the empirical probabilities of heads and tails from the coin toss simulation, thereby completing the final task of summarizing all three objectives.

# %% [markdown]
# ## Generate and Visualize Normal Distribution
#
# ### Subtask:
# Generate data from a Normal Distribution and then visualize it using a histogram, as per Objective 1. This step will build upon the data generation that has already occurred.

# %% [markdown]
# **Reasoning**:
# To visualize the generated Normal Distribution data as requested, I need to import the matplotlib library, create a histogram, and then add appropriate labels and a title before displaying the plot.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(s, bins=50, density=True, alpha=0.6, color='g')
plt.title('Histogram of Normal Distribution (Mean=0, Std Dev=0.1)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
print("Histogram of the Normal Distribution data has been generated and displayed.")
# Out:
# Histogram of the Normal Distribution data has been generated and displayed.

# %% [markdown]
# ## Compute and Display Statistical Parameters
#
# ### Subtask:
# Compute and clearly display the key statistical parameters (mean, median, variance, and standard deviation) for the generated Normal Distribution data, fulfilling Objective 2.

# %% [markdown]
# **Reasoning**:
# The subtask requires printing the computed statistical parameters for the Normal Distribution data. The variables `mean_s`, `median_s`, `variance_s`, and `std_dev_s` already contain these values, so I will print them directly.

# %%
print(f"Mean of Normal Distribution data: {mean_s:.4f}")
print(f"Median of Normal Distribution data: {median_s:.4f}")
print(f"Variance of Normal Distribution data: {variance_s:.4f}")
print(f"Standard Deviation of Normal Distribution data: {std_dev_s:.4f}")
# Out:
# Mean of Normal Distribution data: 0.0039
# Median of Normal Distribution data: -0.0001
# Variance of Normal Distribution data: 0.0098
# Standard Deviation of Normal Distribution data: 0.0992

# %% [markdown]
# ## Display Empirical Probabilities of Coin Toss Simulation
#
# ### Subtask:
# Display the empirical probabilities of heads and tails from the coin toss simulation, thereby fulfilling Objective 3.

# %% [markdown]
# ## Display Empirical Probabilities of Coin Toss Simulation
#
# ### Subtask:
# Display the empirical probabilities of heads and tails from the coin toss simulation, thereby fulfilling Objective 3.

# %% [markdown]
# **Reasoning**:
# To display the empirical probabilities of heads and tails, I will print the `prob_heads` and `prob_tails` variables which already hold these calculated values.

# %%
print(f"Empirical Probability of Heads: {prob_heads:.4f}")
print(f"Empirical Probability of Tails: {prob_tails:.4f}")
# Out:
# Empirical Probability of Heads: 0.4940
# Empirical Probability of Tails: 0.5060

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the completion of all three objectives: data generation and visualization, statistical parameter computation, and random event simulation.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The task was to summarize the completion of three objectives: data generation and visualization, statistical parameter computation, and random event simulation, and to specifically compute and display the mean, median, variance, and standard deviation for the generated Normal Distribution data, and the empirical probabilities of heads and tails from the coin toss simulation. All these tasks were successfully completed.
#
# ### Data Analysis Key Findings
# *   A histogram of the Normal Distribution data (with a mean of 0 and standard deviation of 0.1) was successfully generated and displayed, showing the distribution of values.
# *   The statistical parameters for the generated Normal Distribution data were computed as follows:
#     *   Mean: 0.0039
#     *   Median: -0.0001
#     *   Variance: 0.0098
#     *   Standard Deviation: 0.0992
# *   The empirical probabilities from the coin toss simulation were displayed:
#     *   Empirical Probability of Heads: 0.4940
#     *   Empirical Probability of Tails: 0.5060
#
# ### Insights or Next Steps
# *   The computed statistical parameters for the Normal Distribution are very close to the expected theoretical values (mean close to 0, standard deviation close to 0.1), indicating accurate data generation and calculation.
# *   The empirical probabilities for heads and tails (0.4940 and 0.5060 respectively) are very close to the theoretical probability of 0.5 for a fair coin, suggesting a sufficiently large number of trials in the simulation or a well-implemented simulation.
