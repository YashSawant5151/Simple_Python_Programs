# %% [markdown]
# <a href="https://colab.research.google.com/github/YashSawant5151/Simple_Python_Programs/blob/main/Experiment_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy matplotlib seaborn scikit-learn

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_cls)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(data['rating'])
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.title("Distribution of Ratings")
plt.show()

# %%
print("Accuracy:", accuracy_score(y_test, y_pred_cls))
print(classification_report(y_test, y_pred_cls))
# Out:
# Accuracy: 0.6589646965489885
#               precision    recall  f1-score   support
#
#            0       0.57      0.51      0.54      7829
#            1       0.71      0.75      0.73     12339
#
#     accuracy                           0.66     20168
#    macro avg       0.64      0.63      0.63     20168
# weighted avg       0.65      0.66      0.66     20168

# %%
y_pred_cls = clf.predict(X_test)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_cls, test_size=0.2, random_state=42
)

# %%
y_cls = data['rating_class']

# %%
data['rating_class'] = np.where(data['rating'] >= 3.5, 1, 0)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.9634670620992184

# %%
y_pred = reg.predict(X_test)

# %%
reg = RandomForestRegressor()
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_reg, test_size=0.2, random_state=42
)

# %%
X = data[['userId', 'movieId', 'genres']]
y_reg = data['rating']

# %%
data['genres'] = data['genres'].astype('category').cat.codes

# %%
print(data.shape)
print(data.info())
print(data.describe())
# Out:
# (100836, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
#  4   title      100836 non-null  object
#  5   genres     100836 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.6+ MB
# None
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# ...

# %%
import pandas as pd

ratings = pd.read_csv("/content/sample_data/ratings.csv")
movies = pd.read_csv("/content/sample_data/movies.csv")

data = pd.merge(ratings, movies, on="movieId")

print(data.head())
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report

# %%
pip install scikit-surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp312-cp312-linux_x86_64.whl size=2554966 sha256=cf2c6a6b475066c805f078ce79cfc3d1e4f98de72f4429016f21e9cc22106a74
#   Stored in directory: /root/.cache/pip/wheels/75/fa/bc/739bc2cb1fbaab6061854e6cfbb81a0ae52c92a502a7fa454b
# Successfully built scikit-surprise
# ...
